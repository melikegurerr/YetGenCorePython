# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
telefonrehberi = {
    "Ahmet": "0532 678 13 19",
    "Melike": "0546 453 72 90",
    "Zeynep": "0535 109 76 87",}

def telefonnumarasigoruntule(isim):
    if isim in telefonrehberi:
        return telefonrehberi[isim]
    else:
        return "Bu isme ait bir kayit bulunamadi."

def main():
    isim = input("Lütfen numarasini öğrenmek istediğiniz kişinin adini girin: ")
    telefonnumarasi = telefonnumarasigoruntule(isim)
    print(f"{isim} isimli kişinin numarasi şu şekildedir: {telefon_numarasi}")

if __name__ == "__main__":
    main()

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
calisanlar_indeksi = {
    "Melike Gürer": ["İstanbul", 25, "Mühendis"],
    "Melis Mutluay": ["İzmir", 40, "Direktör"],
    "Ayşe Kaya": ["Ankara", 30, "Pazarlama Müdürü"],
    
}

def calisan_bilgileri_goruntule(isim):
    if isim in calisanlar_indeksi:
        memleket, yas, gorev = calisanlar_indeksi[isim]
        return f"{isim} = Memleket: {memleket} Yaş: {yas} Görev: {gorev}"
    else:
        return "Bu isme ait bir kayıt bulunamadı."

def main():
    isim = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: ")
    calisan_bilgisi = calisan_bilgileri_goruntule(isim)
    print(calisan_bilgisi)

if __name__ == "__main__":
    main()

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
ogrenci_notlari = {
    "Melike": [85, 70, 90],
    "Mehmet": [72, 66, 48],
    "Ece": [62, 70, 50],}
def notlari_goruntule(ogrenci):
    if ogrenci in ogrenci_notlari:
        notlar = ogrenci_notlari[ogrenci]
        not_ortalamasi = sum(notlar) / len(notlar)
        print(f"{ogrenci} isimli öğrencinin")
        for i, not_ in enumerate(notlar, start=1):
            print(f"     {i}.Sınav Notu: {not_}")
        print(f"Not Ortalaması: {not_ortalamasi}")
    else:
        print("Bu isme ait bir öğrenci bulunamadı.")

def main():
    ogrenci = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: ")
    notlari_goruntule(ogrenci)

if __name__ == "__main__":
    main()
# Out:
# Ahmet isimli öğrencinin
#      1.Sınav Notu: 85
#      2.Sınav Notu: 70
#      3.Sınav Notu: 90
# Not Ortalaması: 81.66666666666667

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]

# 2-  Liste Kaç elemanlıdır ?
print("Liste Kaç elemanlıdır ?", len(liste))

# 3-  Listenin ilk ve son elemanı nedir ?
print("Listenin ilk elemanı:", liste[0])
print("Listenin son elemanı:", liste[-1])

# 4-  Mazda değerini Toyota ile değiştirin.
liste[3] = "Toyota"

# 5-  Listenin -2 indeksindeki değer nedir ?
print("Listenin -2 indeksindeki değer:", liste[-2])

# 6-  Listenin ilk 3 elemanını alın.
ilk_uc_eleman = liste[:3]
print("Listenin ilk 3 elemanı:", ilk_uc_eleman)

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
liste[-2:] = ["Toyota", "Renault"]

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
liste.extend(["Audi", "Nissan"])

# 9- Listenin son elemanını silin.
liste.pop()

# 10- Liste elemanlarını tersten yazdırınız.
print("Liste elemanlarını tersten yazdırınız:", liste[::-1])

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
students = [
    {"name": "Yiğit Bilgi", "year": 2010, "grades": (70, 60, 70)},
    {"name": "Sena Turan", "year": 1999, "grades": (80, 80, 70)},
    {"name": "Ahmet Turan", "year": 1998, "grades": (80, 70, 90)}]


# 12- Liste elemanlarını ekrana yazdırınız.

print("Liste elemanlarını ekrana yazdırınız:")
for student in students:
    print(student)

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
liste.append("Cenk")

# 14-  "Sena" değerini listenin başına ekleyiniz.
liste.insert(0, "Sena")

# 15-  "Deniz" ismini listeden siliniz.
if "Deniz" in liste:
    liste.remove("Deniz")

# 16-  "Ali" listenin bir elemanı mıdır ?
ali_var_mi = "Ali" in liste
print("Ali listenin bir elemanı mıdır?", ali_var_mi)

# 17-  Liste elemanlarını ters çevirin.
liste.reverse()
# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
liste.sort()
# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years = [2010, 1999, 1998]
years.sort()

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
marka_listesi = str.split(',')

# 21- years dizisinde kaç tane 1998 değeri vardır ?
sayac = years.count(1998)
print("Years dizisinde 1998 değeri {} defa bulunmaktadır.".format(sayac))

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
markalar = []
for i in range(3):
    marka = input(f"{i+1}. markayı girin: ")
    markalar.append(marka)

print("Kullanıcıdan alınan markalar:", markalar)
# Out:
# Liste Kaç elemanlıdır ? 4
# Listenin ilk elemanı: Bmw
# Listenin son elemanı: Mazda
# Listenin -2 indeksindeki değer: Opel
# Listenin ilk 3 elemanı: ['Bmw', 'Mercedes', 'Opel']
# Liste elemanlarını tersten yazdırınız: ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# Liste elemanlarını ekrana yazdırınız:
# {'name': 'Yiğit Bilgi', 'year': 2010, 'grades': (70, 60, 70)}
# {'name': 'Sena Turan', 'year': 1999, 'grades': (80, 80, 70)}
# {'name': 'Ahmet Turan', 'year': 1998, 'grades': (80, 70, 90)}
# Ali listenin bir elemanı mıdır? False
# Years dizisinde 1998 değeri 1 defa bulunmaktadır.
# Kullanıcıdan alınan markalar: ['mazda', 'porsche', 'ferrari']
